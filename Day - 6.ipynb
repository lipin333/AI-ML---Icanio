# %% [markdown]
# # ***Linear Regression***

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.preprocessing import LabelEncoder

# %%
train = pd.read_csv('/content/car_price_regression_dataset.csv')

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Car_ID        30 non-null     int64
#  1   Brand         30 non-null     object
#  2   Year          30 non-null     int64
#  3   Mileage_km    27 non-null     float64
#  4   Engine_CC     25 non-null     float64
#  5   Fuel_Type     20 non-null     object
#  6   Transmission  20 non-null     object
#  7   Seats         24 non-null     float64
#  8   Car_Price     30 non-null     float64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 2.2+ KB

# %%
train.isnull().sum()
# Out:
# Car_ID           0
# Brand            0
# Year             0
# Mileage_km       3
# Engine_CC        5
# Fuel_Type       10
# Transmission    10
# Seats            6
# Car_Price        0
# dtype: int64

# %%
train.drop('Car_ID',axis=1,inplace=True)

# %%
train['Mileage_km'].fillna(train['Mileage_km'].mean(),inplace=True)
train['Engine_CC'].fillna(train['Engine_CC'].mean(),inplace=True)
train['Seats'].fillna(train['Seats'].mean(),inplace=True)

# %%
train['Engine_CC']=train['Engine_CC'].astype(int)
train['Mileage_km']=train['Mileage_km'].astype(int)
train['Seats']=train['Seats'].astype(int)

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

train['Brand'] = le.fit_transform(train['Brand'])
train['Fuel_Type'] = le.fit_transform(train['Fuel_Type'])
train['Transmission'] = le.fit_transform(train['Transmission'])

# %%
train
# Out:
#     Brand  Year  Mileage_km  ...  Transmission  Seats     Car_Price
# 0       0  2012       79167  ...             2      7  1.570386e+06
# 1       2  2019      195564  ...             2      7  1.626861e+06
# 2       4  2009      165059  ...             2      5  1.658630e+06
# 3       3  2015      173195  ...             0      5  1.639529e+06
# 4       3  2017      109369  ...             0      5  1.024031e+06
# 5       2  2022      164498  ...             2      6  9.518241e+05
# 6       3  2018      131013  ...             1      7  1.433832e+06
# 7       1  2010       59198  ...             2      6  1.205276e+06
# 8       1  2006       35808  ...             2      5  1.382364e+06
# 9       3  2015      138575  ...             0      7  4.821056e+05
# 10      1  2005       82246  ...             1      4  1.888658e+06
# 11      0  2008      157440  ...             0      5  1.685524e+06
# 12      1  2016      158760  ...             1      5  1.985678e+06
# ...

# %%
x = train.drop('Car_Price',axis=1)
y = train['Car_Price']

# %%
model = LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x)

# %%
print("Mean_Squarred Error:",mean_squared_error(y,y_pred))
print("R2 Square:",r2_score(y,y_pred))
print(model.score(x,y))
# Out:
# Mean_Squarred Error: 142026239944.39175
# R2 Square: 0.437722410619946
# 0.437722410619946
